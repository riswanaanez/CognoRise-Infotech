# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/diabetes_prediction_dataset.csv')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease  smoking_history  \
# count  100000.000000  100000.00000  100000.000000    100000.000000
# mean       41.885856       0.07485       0.039420         2.179650
# std        22.516840       0.26315       0.194593         1.889659
# min         0.080000       0.00000       0.000000         0.000000
# 25%        24.000000       0.00000       0.000000         0.000000
# 50%        43.000000       0.00000       0.000000         3.000000
# 75%        60.000000       0.00000       0.000000         4.000000
# max        80.000000       1.00000       1.000000         5.000000
#
#                  bmi    HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000  100000.000000        100000.000000  100000.000000
# mean       27.320767       5.527507           138.058060       0.085000
# std         6.636783       1.070672            40.708136       0.278883
# min        10.010000       3.500000            80.000000       0.000000
# 25%        23.630000       4.800000           100.000000       0.000000
# 50%        27.320000       5.800000           140.000000       0.000000
# 75%        29.580000       6.200000           159.000000       0.000000
# max        95.690000       9.000000           300.000000       1.000000

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='diabetes',data=df,color='red')
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x='diabetes',data=df,hue='gender',color='pink')
# Out:
# <ipython-input-107-c6c5bd806668>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='diabetes',data=df,hue='gender',color='pink')
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.drop(['gender'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['smoking_history']=lb.fit_transform(df['smoking_history'])
df
# Out:
#         age  hypertension  heart_disease  smoking_history    bmi  HbA1c_level  \
# 0      80.0             0              1                4  25.19          6.6
# 1      54.0             0              0                0  27.32          6.6
# 2      28.0             0              0                4  27.32          5.7
# 3      36.0             0              0                1  23.45          5.0
# 4      76.0             1              1                1  20.14          4.8
# ...     ...           ...            ...              ...    ...          ...
# 99995  80.0             0              0                0  27.32          6.2
# 99996   2.0             0              0                0  17.37          6.5
# 99997  66.0             0              0                3  27.83          5.7
# 99998  24.0             0              0                4  35.42          4.0
# 99999  57.0             0              0                1  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# 2                      158         0
# 3                      155         0
# 4                      155         0
# ...                    ...       ...
# 99995                   90         0
# 99996                  100         0
# 99997                  155         0
# 99998                  100         0
# 99999                   90         0
#
# [100000 rows x 8 columns]

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 80.  ,   0.  ,   1.  , ...,  25.19,   6.6 , 140.  ],
#        [ 54.  ,   0.  ,   0.  , ...,  27.32,   6.6 ,  80.  ],
#        [ 28.  ,   0.  ,   0.  , ...,  27.32,   5.7 , 158.  ],
#        ...,
#        [ 66.  ,   0.  ,   0.  , ...,  27.83,   5.7 , 155.  ],
#        [ 24.  ,   0.  ,   0.  , ...,  35.42,   4.  , 100.  ],
#        [ 57.  ,   0.  ,   0.  , ...,  22.43,   6.6 ,  90.  ]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
knn=KNeighborsClassifier(n_neighbors=7)
dt=DecisionTreeClassifier(criterion='entropy')
ab=AdaBoostClassifier(n_estimators=50,random_state=42)
lst=[knn,dt,ab]

# %%
for i in lst:
  print('Model: ',i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print('Confusion Matrix: \n',confusion_matrix(y_test,y_pred))
  print('Accuracy Score: ',accuracy_score(y_test,y_pred))
  print('Classification Report: \n',classification_report(y_test,y_pred))
  print('*'*100)
# Out:
# Model:  KNeighborsClassifier(n_neighbors=7)
# Confusion Matrix:
#  [[27330   123]
#  [ 1004  1543]]
# Accuracy Score:  0.9624333333333334
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     27453
#            1       0.93      0.61      0.73      2547
#
#     accuracy                           0.96     30000
#    macro avg       0.95      0.80      0.86     30000
# weighted avg       0.96      0.96      0.96     30000
#
# ****************************************************************************************************
# Model:  DecisionTreeClassifier(criterion='entropy')
# Confusion Matrix:
#  [[26764   689]
#  [  693  1854]]
# Accuracy Score:  0.9539333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     27453
#            1       0.73      0.73      0.73      2547
#
#     accuracy                           0.95     30000
#    macro avg       0.85      0.85      0.85     30000
# weighted avg       0.95      0.95      0.95     30000
#
# ****************************************************************************************************
# Model:  AdaBoostClassifier(random_state=42)
# Confusion Matrix:
#  [[27421    32]
#  [  816  1731]]
# Accuracy Score:  0.9717333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     27453
#            1       0.98      0.68      0.80      2547
#
#     accuracy                           0.97     30000
#    macro avg       0.98      0.84      0.89     30000
# weighted avg       0.97      0.97      0.97     30000
#
# ****************************************************************************************************
